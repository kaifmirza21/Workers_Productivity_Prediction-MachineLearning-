# %% [markdown]
# date : Date in MM-DD-YYYY
# day : Day of the Week
# quarter : A portion of the month. A month was divided into four quarters
# department : Associated department with the instance
# teamno : Associated team number with the instance
# noofworkers : Number of workers in each team
# noofstylechange : Number of changes in the style of a particular product
# targetedproductivity : Targeted productivity set by the Authority for each team for each day.
# smv : Standard Minute Value, it is the allocated time for a task
# wip : Work in progress. Includes the number of unfinished items for products
# overtime : Represents the amount of overtime by each team in minutes
# incentive : Represents the amount of financial incentive (in BDT) that enables or motivates a particular course of action.
# idletime : The amount of time when the production was interrupted due to several reasons
# idlemen : The number of workers who were idle due to production interruption
# actual_productivity : The actual % of productivity that was delivered by the workers. It ranges from 0-1.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('garments_worker_productivity.csv')
data
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %%
data.columns
# Out:
# Index(['date', 'quarter', 'department', 'day', 'team', 'targeted_productivity',
#        'smv', 'wip', 'over_time', 'incentive', 'idle_time', 'idle_men',
#        'no_of_style_change', 'no_of_workers', 'actual_productivity'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %%
data['wip'].fillna(data['wip'].median(),inplace=True)
data['wip'].isnull().sum()
# Out:
# 0

# %%
data['Date'] = data['date'].str.split('/').str[0]
data['Month'] = data['date'].str.split('/').str[1]
data['Year'] = data['date'].str.split('/').str[2]
data
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    1197 non-null   float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
# ...

# %%
data['Date'] = data['Date'].astype(int)
data['Month'] = data['Month'].astype(int)
data['Year'] = data['Year'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    1197 non-null   float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
# ...

# %%
data.drop('date',axis=1,inplace=True)

# %%
data
# Out:
#        quarter  department        day  team  targeted_productivity    smv  \
# 0     Quarter1      sweing   Thursday     8                   0.80  26.16
# 1     Quarter1  finishing    Thursday     1                   0.75   3.94
# 2     Quarter1      sweing   Thursday    11                   0.80  11.41
# 3     Quarter1      sweing   Thursday    12                   0.80  11.41
# 4     Quarter1      sweing   Thursday     6                   0.80  25.90
# ...        ...         ...        ...   ...                    ...    ...
# 1192  Quarter2   finishing  Wednesday    10                   0.75   2.90
# 1193  Quarter2   finishing  Wednesday     8                   0.70   3.90
# 1194  Quarter2   finishing  Wednesday     7                   0.65   3.90
# 1195  Quarter2   finishing  Wednesday     9                   0.75   2.90
# 1196  Quarter2   finishing  Wednesday     6                   0.70   2.90
#
#          wip  over_time  incentive  idle_time  idle_men  no_of_style_change  \
# ...

# %%
data['quarter'].unique()
# Out:
# array(['Quarter1', 'Quarter2', 'Quarter3', 'Quarter4', 'Quarter5'],
#       dtype=object)

# %%
data['quarter'] = data['quarter'].map({'Quarter1':0,'Quarter2':1,'Quarter3':2,'Quarter4':3,'Quarter5':4})
data
# Out:
#       quarter  department        day  team  targeted_productivity    smv  \
# 0           0      sweing   Thursday     8                   0.80  26.16
# 1           0  finishing    Thursday     1                   0.75   3.94
# 2           0      sweing   Thursday    11                   0.80  11.41
# 3           0      sweing   Thursday    12                   0.80  11.41
# 4           0      sweing   Thursday     6                   0.80  25.90
# ...       ...         ...        ...   ...                    ...    ...
# 1192        1   finishing  Wednesday    10                   0.75   2.90
# 1193        1   finishing  Wednesday     8                   0.70   3.90
# 1194        1   finishing  Wednesday     7                   0.65   3.90
# 1195        1   finishing  Wednesday     9                   0.75   2.90
# 1196        1   finishing  Wednesday     6                   0.70   2.90
#
#          wip  over_time  incentive  idle_time  idle_men  no_of_style_change  \
# ...

# %%
data['department'].unique()
# Out:
# array(['sweing', 'finishing ', 'finishing'], dtype=object)

# %%
data['department'] = data['department'].map({'sweing':0,'finishing ':1,'finishing':1})

# %%
data['department'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.head()
# Out:
#    quarter  department       day  team  targeted_productivity    smv     wip  \
# 0        0           0  Thursday     8                   0.80  26.16  1108.0
# 1        0           1  Thursday     1                   0.75   3.94  1039.0
# 2        0           0  Thursday    11                   0.80  11.41   968.0
# 3        0           0  Thursday    12                   0.80  11.41   968.0
# 4        0           0  Thursday     6                   0.80  25.90  1170.0
#
#    over_time  incentive  idle_time  idle_men  no_of_style_change  \
# 0       7080         98        0.0         0                   0
# 1        960          0        0.0         0                   0
# 2       3660         50        0.0         0                   0
# 3       3660         50        0.0         0                   0
# 4       1920         50        0.0         0                   0
#
#    no_of_workers  actual_productivity  Date  Month  Year
# ...

# %%
data['team'].unique()
# Out:
# array([ 8,  1, 11, 12,  6,  7,  2,  3,  9, 10,  5,  4], dtype=int64)

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder = LabelEncoder()

# %%
data['team'] = labelencoder.fit_transform(data['team'])
data['team']
# Out:
# 0        7
# 1        0
# 2       10
# 3       11
# 4        5
#         ..
# 1192     9
# 1193     7
# 1194     6
# 1195     8
# 1196     5
# Name: team, Length: 1197, dtype: int64

# %%
data['day'] = labelencoder.fit_transform(data['day'])
data['day']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1192    5
# 1193    5
# 1194    5
# 1195    5
# 1196    5
# Name: day, Length: 1197, dtype: int32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   quarter                1197 non-null   int64
#  1   department             1197 non-null   int64
#  2   day                    1197 non-null   int32
#  3   team                   1197 non-null   int64
#  4   targeted_productivity  1197 non-null   float64
#  5   smv                    1197 non-null   float64
#  6   wip                    1197 non-null   float64
#  7   over_time              1197 non-null   int64
#  8   incentive              1197 non-null   int64
#  9   idle_time              1197 non-null   float64
#  10  idle_men               1197 non-null   int64
#  11  no_of_style_change     1197 non-null   int64
#  12  no_of_workers          1197 non-null   float64
#  13  actual_productivity    1197 non-null   float64
# ...

# %%
data
# Out:
#       quarter  department  day  team  targeted_productivity    smv     wip  \
# 0           0           0    3     7                   0.80  26.16  1108.0
# 1           0           1    3     0                   0.75   3.94  1039.0
# 2           0           0    3    10                   0.80  11.41   968.0
# 3           0           0    3    11                   0.80  11.41   968.0
# 4           0           0    3     5                   0.80  25.90  1170.0
# ...       ...         ...  ...   ...                    ...    ...     ...
# 1192        1           1    5     9                   0.75   2.90  1039.0
# 1193        1           1    5     7                   0.70   3.90  1039.0
# 1194        1           1    5     6                   0.65   3.90  1039.0
# 1195        1           1    5     8                   0.75   2.90  1039.0
# 1196        1           1    5     5                   0.70   2.90  1039.0
#
# ...

# %%
x = data.iloc[:,0:17]
x.drop('actual_productivity',axis=1,inplace=True)
x
# Out:
#       quarter  department  day  team  targeted_productivity    smv     wip  \
# 0           0           0    3     7                   0.80  26.16  1108.0
# 1           0           1    3     0                   0.75   3.94  1039.0
# 2           0           0    3    10                   0.80  11.41   968.0
# 3           0           0    3    11                   0.80  11.41   968.0
# 4           0           0    3     5                   0.80  25.90  1170.0
# ...       ...         ...  ...   ...                    ...    ...     ...
# 1192        1           1    5     9                   0.75   2.90  1039.0
# 1193        1           1    5     7                   0.70   3.90  1039.0
# 1194        1           1    5     6                   0.65   3.90  1039.0
# 1195        1           1    5     8                   0.75   2.90  1039.0
# 1196        1           1    5     5                   0.70   2.90  1039.0
#
# ...

# %%
y = data['actual_productivity']
y
# Out:
# 0       0.940725
# 1       0.886500
# 2       0.800570
# 3       0.800570
# 4       0.800382
#           ...
# 1192    0.628333
# 1193    0.625625
# 1194    0.625625
# 1195    0.505889
# 1196    0.394722
# Name: actual_productivity, Length: 1197, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import mean_squared_error

# %%
model = Sequential([
    Dense(units=16,input_shape=(16,),activation='linear'),
    Dense(units=32,activation='linear'),
    Dense(units=1,activation='linear'),
])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 16)                272
#
#  dense_16 (Dense)            (None, 32)                544
#
#  dense_17 (Dense)            (None, 1)                 33
#
# ...
# Total params: 849
# Trainable params: 849
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mean_squared_error',metrics=['mean_squared_error'])

# %%
model.fit(x=x_train, y=y_train, batch_size=30, epochs=50, shuffle=True, verbose=2)
# Out:
# Epoch 1/50
# 28/28 - 0s - loss: 56.2646 - mean_squared_error: 56.2646 - 182ms/epoch - 6ms/step
# Epoch 2/50
# 28/28 - 0s - loss: 26.6675 - mean_squared_error: 26.6675 - 176ms/epoch - 6ms/step
# Epoch 3/50
# 28/28 - 0s - loss: 5.6290 - mean_squared_error: 5.6290 - 184ms/epoch - 7ms/step
# Epoch 4/50
# 28/28 - 0s - loss: 1.5466 - mean_squared_error: 1.5466 - 184ms/epoch - 7ms/step
# Epoch 5/50
# 28/28 - 0s - loss: 1.3511 - mean_squared_error: 1.3511 - 296ms/epoch - 11ms/step
# Epoch 6/50
# 28/28 - 0s - loss: 1.3529 - mean_squared_error: 1.3529 - 327ms/epoch - 12ms/step
# Epoch 7/50
# 28/28 - 0s - loss: 1.3448 - mean_squared_error: 1.3448 - 196ms/epoch - 7ms/step
# Epoch 8/50
# 28/28 - 0s - loss: 1.1782 - mean_squared_error: 1.1782 - 225ms/epoch - 8ms/step
# Epoch 9/50
# 28/28 - 1s - loss: 1.1396 - mean_squared_error: 1.1396 - 513ms/epoch - 18ms/step
# Epoch 10/50
# 28/28 - 1s - loss: 1.1298 - mean_squared_error: 1.1298 - 587ms/epoch - 21ms/step
# Epoch 11/50
# ...

# %%
predictions = model.predict(x_test)
# Out:
# 12/12 [==============================] - 1s 7ms/step

# %%
predictions
# Out:
# array([[ 2.5542698 ],
#        [ 0.16691019],
#        [ 0.716074  ],
#        [ 1.1524601 ],
#        [ 0.29621318],
#        [-0.58062935],
#        [ 1.0207005 ],
#        [ 1.2373142 ],
#        [ 0.08548929],
#        [ 0.46555522],
#        [ 1.2284946 ],
#        [ 0.28568462],
#        [ 2.0019932 ],
#        [ 0.68409157],
#        [ 2.5093784 ],
#        [ 2.3274937 ],
#        [-0.05208395],
#        [ 0.83873177],
#        [ 0.753458  ],
#        [-0.46733662],
#        [ 1.7944736 ],
#        [ 1.7307835 ],
#        [ 1.2947178 ],
#        [ 0.5351658 ],
#        [ 0.05265238],
#        [ 0.00712015],
#        [ 1.1606083 ],
#        [ 0.43997386],
#        [ 1.0210514 ],
#        [ 1.0948277 ],
#        [ 1.9702854 ],
#        [ 0.43911937],
#        [ 0.06534769],
#        [ 1.5690708 ],
#        [ 1.5774021 ],
#        [ 0.64422035],
#        [ 0.51078224],
#        [ 1.2568913 ],
#        [ 1.6051426 ],
#        [ 1.0932865 ],
#        [ 0.4533787 ],
# ...

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,predictions)
# Out:
# 0.7451488266976346

# %%
model.save('model.h5')

# %%
from tensorflow.keras.models import load_model

model = load_model('model.h5')
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 16)                272
#
#  dense_16 (Dense)            (None, 32)                544
#
#  dense_17 (Dense)            (None, 1)                 33
#
# ...
# Total params: 849
# Trainable params: 849
# Non-trainable params: 0
# _________________________________________________________________
